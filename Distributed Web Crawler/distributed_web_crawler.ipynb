# %% [markdown]
# # Distributed Web Crawler
#
# This notebook implements a distributed web crawler using Apache Spark and Python. It demonstrates:
# - Distributed crawling across multiple machines
# - Parallel processing for improved performance
# - Fault tolerance and error handling
# - Data extraction and analysis

# %% [markdown]
# ## 1. Setup and Installation

# %%
# Install Java and Spark
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.5/spark-3.5.5-bin-hadoop3.tgz #if already installed
# !tar -xzf spark-3.5.5-bin-hadoop3.tgz
# !pip install -q findspark requests beautifulsoup4 pandas matplotlib

# %% [markdown]
# ## 2. Initialize Spark Environment

# %%
import os
import findspark
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
findspark.init("spark-3.5.5-bin-hadoop3")

# Initialize Spark
from pyspark.sql import SparkSession
from pyspark import SparkContext
spark = SparkSession.builder.appName("BigDistributedCrawler").getOrCreate()
sc = SparkContext.getOrCreate()

print("✅ Spark initialized successfully!")
# Out:
# DEBUG:py4j.clientserver:Command to send: r
# u
# SparkSession$
# rj
# e
#
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Command to send: r
# u
# SparkSession$
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.sql.SparkSession$
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.sql.SparkSession$
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.sql.SparkSession$
# MODULE$
# e
#
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.sql.SparkSession$
# MODULE$
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro69
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Answer received: !yro69
# DEBUG:py4j.clientserver:Command to send: i
# java.util.HashMap
# e
#
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Command to send: i
# java.util.HashMap
# e
#
# DEBUG:py4j.clientserver:Answer received: !yao70
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Answer received: !yao70
# DEBUG:py4j.clientserver:Command to send: c
# o70
# put
# sspark.app.name
# sBigDistributedCrawler
# e
#
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Command to send: c
# o70
# put
# sspark.app.name
# sBigDistributedCrawler
# e
#
# DEBUG:py4j.clientserver:Answer received: !yn
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Answer received: !yn
# DEBUG:py4j.clientserver:Command to send: c
# o69
# applyModifiableSettings
# ro24
# ro70
# e
#
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Command to send: c
# o69
# applyModifiableSettings
# ro24
# ro70
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:34:34 [py4j.clientserver] DEBUG: Answer received: !yv
# ✅ Spark initialized successfully!

# %% [markdown]
# ## 3. Define Crawler Functions

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

def crawl_page(url, max_links=50, max_images=30, max_scripts=30):
    try:
        headers = {'User-Agent': 'Mozilla/5.0'}
        response = requests.get(url, headers=headers, timeout=10, allow_redirects=True)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.title.string.strip() if soup.title else "No Title"

        # Meta tags
        meta_desc = soup.find("meta", attrs={"name": "description"})
        meta_keywords = soup.find("meta", attrs={"name": "keywords"})
        meta_desc = meta_desc.get("content", "") if meta_desc else ""
        meta_keywords = meta_keywords.get("content", "") if meta_keywords else ""

        # Links
        raw_links = [a['href'] for a in soup.find_all('a', href=True)]
        unique_links = list(set([
            urljoin(url, link) for link in raw_links
            if urlparse(urljoin(url, link)).scheme in ['http', 'https']
        ]))[:max_links]

        # Images
        raw_images = [img['src'] for img in soup.find_all('img', src=True)]
        unique_images = list(set([urljoin(url, img) for img in raw_images]))[:max_images]

        # Scripts
        raw_scripts = [script['src'] for script in soup.find_all('script', src=True)]
        unique_scripts = list(set([urljoin(url, script) for script in raw_scripts]))[:max_scripts]

        return {
            'original_url': url,
            'final_url': response.url,
            'status_code': response.status_code,
            'content_type': response.headers.get('Content-Type', ''),
            'title': title,
            'meta_description': meta_desc,
            'meta_keywords': meta_keywords,
            'link_count': len(unique_links),
            'links': unique_links,
            'image_count': len(unique_images),
            'images': unique_images,
            'script_count': len(unique_scripts),
            'scripts': unique_scripts
        }
    except Exception as e:
        return {'url': url, 'error': str(e)}

# %% [markdown]
# ## 4. Define Seed URLs and Start Crawling

# %%
# Seed URLs
seed_urls = [
    "https://www.wikipedia.org", "https://www.bbc.com", "https://edition.cnn.com",
    "https://www.python.org", "https://www.stackoverflow.com", "https://www.github.com",
    "https://www.nytimes.com", "https://www.microsoft.com", "https://www.oracle.com",
    "https://www.reddit.com", "https://www.mozilla.org", "https://www.nationalgeographic.com",
    "https://www.forbes.com", "https://www.ted.com", "https://www.medium.com",
    "https://www.theguardian.com", "https://www.bloomberg.com", "https://www.amazon.com",
    "https://www.apple.com", "https://www.linkedin.com"
]

def crawl_with_progress(url):
    result = crawl_page(url)
    print(f"{'Success' if 'error' not in result else 'Failed'}: {url}")
    return result

# Start distributed crawling
rdd = sc.parallelize(seed_urls, numSlices=4)
results = rdd.map(crawl_with_progress).collect()
# Out:
# DEBUG:py4j.clientserver:Command to send: r
# u
# PythonRDD
# rj
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: r
# u
# PythonRDD
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.PythonRDD
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.PythonRDD
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.api.python.PythonRDD
# readRDDFromFile
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.api.python.PythonRDD
# readRDDFromFile
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.api.python.PythonRDD
# readRDDFromFile
# ro13
# s/tmp/spark-ea4e815a-3a95-4498-9640-376ec7e2ccce/pyspark-b974c492-a8d1-4998-a256-89bda405ea29/tmp16c0t_8g
# i4
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.api.python.PythonRDD
# readRDDFromFile
# ro13
# s/tmp/spark-ea4e815a-3a95-4498-9640-376ec7e2ccce/pyspark-b974c492-a8d1-4998-a256-89bda405ea29/tmp16c0t_8g
# i4
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro71
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !yro71
# DEBUG:py4j.clientserver:Command to send: c
# o71
# id
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: c
# o71
# id
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi20
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !yi20
# DEBUG:py4j.clientserver:Command to send: c
# o71
# rdd
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: c
# o71
# rdd
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro72
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !yro72
# DEBUG:py4j.clientserver:Command to send: c
# o72
# isBarrier
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: c
# o72
# isBarrier
# e
#
# DEBUG:py4j.clientserver:Answer received: !ybfalse
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !ybfalse
# DEBUG:py4j.clientserver:Command to send: c
# o13
# setCallSite
# scollect at <ipython-input-25-3a749ea03034>:19
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: c
# o13
# setCallSite
# scollect at <ipython-input-25-3a749ea03034>:19
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: r
# u
# PythonRDD
# rj
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: r
# u
# PythonRDD
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.PythonRDD
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.PythonRDD
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.api.python.PythonRDD
# collectAndServe
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.api.python.PythonRDD
# collectAndServe
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: r
# u
# PythonUtils
# rj
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: r
# u
# PythonUtils
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.PythonUtils
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# e
#
# 2025-05-11 15:35:07 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# ro13
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# ro13
# e
#
# DEBUG:py4j.clientserver:Answer received: !yL1048576
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yL1048576
# DEBUG:py4j.clientserver:Command to send: r
# u
# SimplePythonFunction
# rj
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: r
# u
# SimplePythonFunction
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.SimplePythonFunction
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.SimplePythonFunction
# DEBUG:py4j.clientserver:Command to send: i
# java.util.HashMap
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: i
# java.util.HashMap
# e
#
# DEBUG:py4j.clientserver:Answer received: !yao73
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yao73
# DEBUG:py4j.clientserver:Command to send: c
# o73
# put
# sPYTHONHASHSEED
# s0
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: c
# o73
# put
# sPYTHONHASHSEED
# s0
# e
#
# DEBUG:py4j.clientserver:Answer received: !yn
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yn
# DEBUG:py4j.clientserver:Command to send: i
# java.util.ArrayList
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: i
# java.util.ArrayList
# e
#
# DEBUG:py4j.clientserver:Answer received: !ylo74
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !ylo74
# DEBUG:py4j.clientserver:Command to send: i
# java.util.ArrayList
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: i
# java.util.ArrayList
# e
#
# DEBUG:py4j.clientserver:Answer received: !ylo75
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !ylo75
# DEBUG:py4j.clientserver:Command to send: i
# org.apache.spark.api.python.SimplePythonFunction
# ...
# ro73
# ro74
# s/usr/bin/python3
# s3.11
# ro75
# ro16
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: i
# org.apache.spark.api.python.SimplePythonFunction
# ...
# ro73
# ro74
# s/usr/bin/python3
# s3.11
# ro75
# ro16
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro76
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yro76
# DEBUG:py4j.clientserver:Command to send: r
# u
# PythonRDD
# rj
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: r
# u
# PythonRDD
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.PythonRDD
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.PythonRDD
# DEBUG:py4j.clientserver:Command to send: c
# o71
# rdd
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: c
# o71
# rdd
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro77
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yro77
# DEBUG:py4j.clientserver:Command to send: i
# org.apache.spark.api.python.PythonRDD
# ro77
# ro76
# bFalse
# bFalse
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: i
# org.apache.spark.api.python.PythonRDD
# ro77
# ro76
# bFalse
# bFalse
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro78
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yro78
# DEBUG:py4j.clientserver:Command to send: c
# o78
# asJavaRDD
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: c
# o78
# asJavaRDD
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro79
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yro79
# DEBUG:py4j.clientserver:Command to send: c
# o79
# rdd
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: c
# o79
# rdd
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro80
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yro80
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.api.python.PythonRDD
# collectAndServe
# ro80
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.api.python.PythonRDD
# collectAndServe
# ro80
# e
#
# DEBUG:py4j.clientserver:Command to send: m
# d
# o67
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: m
# d
# o67
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o69
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: m
# d
# o69
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o72
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: m
# d
# o72
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o73
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: m
# d
# o73
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o74
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: m
# d
# o74
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o75
# e
#
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Command to send: m
# d
# o75
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:08 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Answer received: !yto81
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yto81
# DEBUG:py4j.clientserver:Command to send: c
# o13
# setCallSite
# n
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o13
# setCallSite
# n
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: a
# e
# o81
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: a
# e
# o81
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi3
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yi3
# DEBUG:py4j.clientserver:Command to send: a
# g
# o81
# i0
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: a
# g
# o81
# i0
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi37521
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yi37521
# DEBUG:py4j.clientserver:Command to send: a
# e
# o81
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: a
# e
# o81
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi3
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yi3
# DEBUG:py4j.clientserver:Command to send: a
# g
# o81
# i1
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: a
# g
# o81
# i1
# e
#
# DEBUG:py4j.clientserver:Answer received: !ysc89812fd1a1c006df11698c50917dd52f612312101b1ebd7a6d43e106d22d6ae
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ysc89812fd1a1c006df11698c50917dd52f612312101b1ebd7a6d43e106d22d6ae

# %% [markdown]
# ## 5. Process and Save Results

# %%
from pyspark.sql import Row
import datetime

# Separate successes and failures
successes = [r for r in results if 'error' not in r and r.get('links')]
failures = [r for r in results if 'error' in r]

# Convert to DataFrame
clean_rows = [
    Row(
        url=r['original_url'],
        final_url=r.get('final_url', ''),
        status_code=r.get('status_code', ''),
        content_type=r.get('content_type', ''),
        title=r.get('title', 'No Title'),
        meta_description=r.get('meta_description', ''),
        meta_keywords=r.get('meta_keywords', ''),
        link_count=r.get('link_count', 0),
        links=", ".join(r.get('links', [])),
        image_count=r.get('image_count', 0),
        images=", ".join(r.get('images', [])),
        script_count=r.get('script_count', 0),
        scripts=", ".join(r.get('scripts', []))
    )
    for r in successes
]

clean_df = spark.createDataFrame(clean_rows)

# Save results
def save_clean_df(df):
    import shutil
    output_csv_path = "cleaned_crawled_data_csv"
    output_parquet_path = "cleaned_crawled_data_parquet"

    shutil.rmtree(output_csv_path, ignore_errors=True)
    shutil.rmtree(output_parquet_path, ignore_errors=True)

    if df.count() > 0:
        df.write.mode("overwrite").option("header", True).csv(output_csv_path)
        df.write.mode("overwrite").parquet(output_parquet_path)
        df.limit(5).toPandas().to_csv("sample_cleaned_crawled_data.csv", index=False)
        print("✅ Cleaned crawl data saved to CSV, Parquet, and sample CSV.")
    else:
        print("⚠️ No data to save: clean_df is empty.")

# Pass the 'clean_df' DataFrame to the function
save_clean_df(clean_df) # This line was changed to include the DataFrame as argument.
# Out:
# DEBUG:py4j.clientserver:Command to send: r
# u
# SparkSession
# rj
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# u
# SparkSession
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.sql.SparkSession
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.sql.SparkSession
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.sql.SparkSession
# setActiveSession
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.sql.SparkSession
# setActiveSession
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.sql.SparkSession
# setActiveSession
# ro24
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.sql.SparkSession
# setActiveSession
# ro24
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: c
# o24
# sessionState
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o24
# sessionState
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro82
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro82
# DEBUG:py4j.clientserver:Command to send: c
# o82
# conf
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o82
# conf
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro83
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro83
# DEBUG:py4j.clientserver:Command to send: c
# o83
# inferDictAsStruct
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o83
# inferDictAsStruct
# e
#
# DEBUG:py4j.clientserver:Answer received: !ybfalse
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ybfalse
# DEBUG:py4j.clientserver:Command to send: c
# o24
# sessionState
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o24
# sessionState
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro84
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro84
# DEBUG:py4j.clientserver:Command to send: c
# o84
# conf
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o84
# conf
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro85
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro85
# DEBUG:py4j.clientserver:Command to send: c
# o85
# legacyInferArrayTypeFromFirstElement
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o85
# legacyInferArrayTypeFromFirstElement
# e
#
# DEBUG:py4j.clientserver:Answer received: !ybfalse
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ybfalse
# DEBUG:py4j.clientserver:Command to send: r
# u
# PythonSQLUtils
# rj
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# u
# PythonSQLUtils
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.sql.api.python.PythonSQLUtils
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.sql.api.python.PythonSQLUtils
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.sql.api.python.PythonSQLUtils
# isTimestampNTZPreferred
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.sql.api.python.PythonSQLUtils
# isTimestampNTZPreferred
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.sql.api.python.PythonSQLUtils
# isTimestampNTZPreferred
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.sql.api.python.PythonSQLUtils
# isTimestampNTZPreferred
# e
#
# DEBUG:py4j.clientserver:Answer received: !ybfalse
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ybfalse
# DEBUG:py4j.clientserver:Command to send: c
# o13
# sc
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o13
# sc
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro86
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro86
# DEBUG:py4j.clientserver:Command to send: c
# o86
# defaultParallelism
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o86
# defaultParallelism
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi2
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yi2
# DEBUG:py4j.clientserver:Command to send: r
# u
# PythonRDD
# rj
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# u
# PythonRDD
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.PythonRDD
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.PythonRDD
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.api.python.PythonRDD
# readRDDFromFile
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.api.python.PythonRDD
# readRDDFromFile
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.api.python.PythonRDD
# readRDDFromFile
# ro13
# s/tmp/spark-ea4e815a-3a95-4498-9640-376ec7e2ccce/pyspark-b974c492-a8d1-4998-a256-89bda405ea29/tmp4s0p16hn
# i2
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.api.python.PythonRDD
# readRDDFromFile
# ro13
# s/tmp/spark-ea4e815a-3a95-4498-9640-376ec7e2ccce/pyspark-b974c492-a8d1-4998-a256-89bda405ea29/tmp4s0p16hn
# i2
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro87
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro87
# DEBUG:py4j.clientserver:Command to send: c
# o87
# id
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o87
# id
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi22
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yi22
# DEBUG:py4j.clientserver:Command to send: r
# u
# SerDeUtil
# rj
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# u
# SerDeUtil
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.SerDeUtil
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.SerDeUtil
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.api.python.SerDeUtil
# toJavaArray
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.api.python.SerDeUtil
# toJavaArray
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: c
# o87
# rdd
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o87
# rdd
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro88
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro88
# DEBUG:py4j.clientserver:Command to send: c
# o88
# isBarrier
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o88
# isBarrier
# e
#
# DEBUG:py4j.clientserver:Answer received: !ybfalse
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ybfalse
# DEBUG:py4j.clientserver:Command to send: r
# u
# SerDeUtil
# rj
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# u
# SerDeUtil
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.SerDeUtil
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.SerDeUtil
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.api.python.SerDeUtil
# pythonToJava
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.api.python.SerDeUtil
# pythonToJava
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: r
# u
# PythonUtils
# rj
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# u
# PythonUtils
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.PythonUtils
# DEBUG:py4j.clientserver:Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# e
#
# DEBUG:py4j.clientserver:Answer received: !ym
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ym
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# ro13
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# ro13
# e
#
# DEBUG:py4j.clientserver:Answer received: !yL1048576
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yL1048576
# DEBUG:py4j.clientserver:Command to send: r
# u
# SimplePythonFunction
# rj
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# u
# SimplePythonFunction
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.SimplePythonFunction
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.SimplePythonFunction
# DEBUG:py4j.clientserver:Command to send: i
# java.util.HashMap
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: i
# java.util.HashMap
# e
#
# DEBUG:py4j.clientserver:Answer received: !yao89
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yao89
# DEBUG:py4j.clientserver:Command to send: c
# o89
# put
# sPYTHONHASHSEED
# s0
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o89
# put
# sPYTHONHASHSEED
# s0
# e
#
# DEBUG:py4j.clientserver:Answer received: !yn
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yn
# DEBUG:py4j.clientserver:Command to send: i
# java.util.ArrayList
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: i
# java.util.ArrayList
# e
#
# DEBUG:py4j.clientserver:Answer received: !ylo90
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ylo90
# DEBUG:py4j.clientserver:Command to send: i
# java.util.ArrayList
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: i
# java.util.ArrayList
# e
#
# DEBUG:py4j.clientserver:Answer received: !ylo91
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ylo91
# DEBUG:py4j.clientserver:Command to send: i
# org.apache.spark.api.python.SimplePythonFunction
# ...
# ro89
# ro90
# s/usr/bin/python3
# s3.11
# ro91
# ro16
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: i
# org.apache.spark.api.python.SimplePythonFunction
# ...
# ro89
# ro90
# s/usr/bin/python3
# s3.11
# ro91
# ro16
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro92
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro92
# DEBUG:py4j.clientserver:Command to send: r
# u
# PythonRDD
# rj
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: r
# u
# PythonRDD
# rj
# e
#
# DEBUG:py4j.clientserver:Answer received: !ycorg.apache.spark.api.python.PythonRDD
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !ycorg.apache.spark.api.python.PythonRDD
# DEBUG:py4j.clientserver:Command to send: c
# o87
# rdd
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o87
# rdd
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro93
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro93
# DEBUG:py4j.clientserver:Command to send: i
# org.apache.spark.api.python.PythonRDD
# ro93
# ro92
# bTrue
# bFalse
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: i
# org.apache.spark.api.python.PythonRDD
# ro93
# ro92
# bTrue
# bFalse
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro94
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro94
# DEBUG:py4j.clientserver:Command to send: c
# o94
# asJavaRDD
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o94
# asJavaRDD
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro95
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro95
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.api.python.SerDeUtil
# pythonToJava
# ro95
# bTrue
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.api.python.SerDeUtil
# pythonToJava
# ro95
# bTrue
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro96
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro96
# DEBUG:py4j.clientserver:Command to send: c
# z:org.apache.spark.api.python.SerDeUtil
# toJavaArray
# ro96
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# z:org.apache.spark.api.python.SerDeUtil
# toJavaArray
# ro96
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro97
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro97
# DEBUG:py4j.clientserver:Command to send: c
# o97
# rdd
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o97
# rdd
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro98
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yro98
# DEBUG:py4j.clientserver:Command to send: c
# o24
# applySchemaToPythonRDD
# ro98
# s{"fields":[{"metadata":{},"name":"url","nullable":true,"type":"string"},{"metadata":{},"name":"final_url","nullable":true,"type":"string"},{"metadata":{},"name":"status_code","nullable":true,"type":"long"},{"metadata":{},"name":"content_type","nullable":true,"type":"string"},{"metadata":{},"name":"title","nullable":true,"type":"string"},{"metadata":{},"name":"meta_description","nullable":true,"type":"string"},{"metadata":{},"name":"meta_keywords","nullable":true,"type":"string"},{"metadata":{},"name":"link_count","nullable":true,"type":"long"},{"metadata":{},"name":"links","nullable":true,"type":"string"},{"metadata":{},"name":"image_count","nullable":true,"type":"long"},{"metadata":{},"name":"images","nullable":true,"type":"string"},{"metadata":{},"name":"script_count","nullable":true,"type":"long"},{"metadata":{},"name":"scripts","nullable":true,"type":"string"}],"type":"struct"}
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: c
# o24
# applySchemaToPythonRDD
# ro98
# s{"fields":[{"metadata":{},"name":"url","nullable":true,"type":"string"},{"metadata":{},"name":"final_url","nullable":true,"type":"string"},{"metadata":{},"name":"status_code","nullable":true,"type":"long"},{"metadata":{},"name":"content_type","nullable":true,"type":"string"},{"metadata":{},"name":"title","nullable":true,"type":"string"},{"metadata":{},"name":"meta_description","nullable":true,"type":"string"},{"metadata":{},"name":"meta_keywords","nullable":true,"type":"string"},{"metadata":{},"name":"link_count","nullable":true,"type":"long"},{"metadata":{},"name":"links","nullable":true,"type":"string"},{"metadata":{},"name":"image_count","nullable":true,"type":"long"},{"metadata":{},"name":"images","nullable":true,"type":"string"},{"metadata":{},"name":"script_count","nullable":true,"type":"long"},{"metadata":{},"name":"scripts","nullable":true,"type":"string"}],"type":"struct"}
# e
#
# DEBUG:py4j.clientserver:Command to send: m
# d
# o81
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: m
# d
# o81
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o76
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: m
# d
# o76
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o77
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: m
# d
# o77
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o78
# e
#
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Command to send: m
# d
# o78
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:20 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o79
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: m
# d
# o79
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro99
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yro99
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: c
# o99
# count
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: c
# o99
# count
# e
#
# DEBUG:py4j.clientserver:Command to send: m
# d
# o80
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: m
# d
# o80
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o82
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: m
# d
# o82
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o83
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: m
# d
# o83
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o84
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: m
# d
# o84
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o89
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: m
# d
# o89
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o90
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: m
# d
# o90
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: m
# d
# o91
# e
#
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Command to send: m
# d
# o91
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:21 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Answer received: !yL16
# 2025-05-11 15:35:22 [py4j.clientserver] DEBUG: Answer received: !yL16
# DEBUG:py4j.clientserver:Command to send: c
# o99
# write
# e
#
# 2025-05-11 15:35:22 [py4j.clientserver] DEBUG: Command to send: c
# o99
# write
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro100
# 2025-05-11 15:35:22 [py4j.clientserver] DEBUG: Answer received: !yro100
# DEBUG:py4j.clientserver:Command to send: c
# o100
# mode
# soverwrite
# e
#
# 2025-05-11 15:35:22 [py4j.clientserver] DEBUG: Command to send: c
# o100
# mode
# soverwrite
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro101
# 2025-05-11 15:35:22 [py4j.clientserver] DEBUG: Answer received: !yro101
# DEBUG:py4j.clientserver:Command to send: c
# o101
# option
# sheader
# strue
# e
#
# 2025-05-11 15:35:22 [py4j.clientserver] DEBUG: Command to send: c
# o101
# option
# sheader
# strue
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro102
# 2025-05-11 15:35:22 [py4j.clientserver] DEBUG: Answer received: !yro102
# DEBUG:py4j.clientserver:Command to send: c
# o102
# csv
# scleaned_crawled_data_csv
# e
#
# 2025-05-11 15:35:22 [py4j.clientserver] DEBUG: Command to send: c
# o102
# csv
# scleaned_crawled_data_csv
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: c
# o99
# write
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o99
# write
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro103
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !yro103
# DEBUG:py4j.clientserver:Command to send: c
# o103
# mode
# soverwrite
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o103
# mode
# soverwrite
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro104
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !yro104
# DEBUG:py4j.clientserver:Command to send: c
# o104
# parquet
# scleaned_crawled_data_parquet
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o104
# parquet
# scleaned_crawled_data_parquet
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: c
# o99
# limit
# i5
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o99
# limit
# i5
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro105
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !yro105
# DEBUG:py4j.clientserver:Command to send: c
# o24
# sessionState
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o24
# sessionState
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro106
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !yro106
# DEBUG:py4j.clientserver:Command to send: c
# o106
# conf
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o106
# conf
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro107
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !yro107
# DEBUG:py4j.clientserver:Command to send: c
# o107
# arrowPySparkEnabled
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o107
# arrowPySparkEnabled
# e
#
# DEBUG:py4j.clientserver:Answer received: !ybfalse
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !ybfalse
# DEBUG:py4j.clientserver:Command to send: c
# o13
# setCallSite
# stoPandas at <ipython-input-26-384e31064874>:42
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o13
# setCallSite
# stoPandas at <ipython-input-26-384e31064874>:42
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: c
# o105
# collectToPython
# e
#
# 2025-05-11 15:35:23 [py4j.clientserver] DEBUG: Command to send: c
# o105
# collectToPython
# e
#
# DEBUG:py4j.clientserver:Answer received: !yto108
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !yto108
# DEBUG:py4j.clientserver:Command to send: c
# o13
# setCallSite
# n
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: c
# o13
# setCallSite
# n
# e
#
# DEBUG:py4j.clientserver:Answer received: !yv
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !yv
# DEBUG:py4j.clientserver:Command to send: a
# e
# o108
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: a
# e
# o108
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi3
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !yi3
# DEBUG:py4j.clientserver:Command to send: a
# g
# o108
# i0
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: a
# g
# o108
# i0
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi37179
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !yi37179
# DEBUG:py4j.clientserver:Command to send: a
# e
# o108
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: a
# e
# o108
# e
#
# DEBUG:py4j.clientserver:Answer received: !yi3
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !yi3
# DEBUG:py4j.clientserver:Command to send: a
# g
# o108
# i1
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: a
# g
# o108
# i1
# e
#
# DEBUG:py4j.clientserver:Answer received: !ysc89812fd1a1c006df11698c50917dd52f612312101b1ebd7a6d43e106d22d6ae
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !ysc89812fd1a1c006df11698c50917dd52f612312101b1ebd7a6d43e106d22d6ae
# DEBUG:py4j.clientserver:Command to send: c
# o105
# schema
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: c
# o105
# schema
# e
#
# DEBUG:py4j.clientserver:Answer received: !yro109
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !yro109
# DEBUG:py4j.clientserver:Command to send: c
# o109
# json
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: c
# o109
# json
# e
#
# DEBUG:py4j.clientserver:Answer received: !ys{"type":"struct","fields":[{"name":"url","type":"string","nullable":true,"metadata":{}},{"name":"final_url","type":"string","nullable":true,"metadata":{}},{"name":"status_code","type":"long","nullable":true,"metadata":{}},{"name":"content_type","type":"string","nullable":true,"metadata":{}},{"name":"title","type":"string","nullable":true,"metadata":{}},{"name":"meta_description","type":"string","nullable":true,"metadata":{}},{"name":"meta_keywords","type":"string","nullable":true,"metadata":{}},{"name":"link_count","type":"long","nullable":true,"metadata":{}},{"name":"links","type":"string","nullable":true,"metadata":{}},{"name":"image_count","type":"long","nullable":true,"metadata":{}},{"name":"images","type":"string","nullable":true,"metadata":{}},{"name":"script_count","type":"long","nullable":true,"metadata":{}},{"name":"scripts","type":"string","nullable":true,"metadata":{}}]}
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !ys{"type":"struct","fields":[{"name":"url","type":"string","nullable":true,"metadata":{}},{"name":"final_url","type":"string","nullable":true,"metadata":{}},{"name":"status_code","type":"long","nullable":true,"metadata":{}},{"name":"content_type","type":"string","nullable":true,"metadata":{}},{"name":"title","type":"string","nullable":true,"metadata":{}},{"name":"meta_description","type":"string","nullable":true,"metadata":{}},{"name":"meta_keywords","type":"string","nullable":true,"metadata":{}},{"name":"link_count","type":"long","nullable":true,"metadata":{}},{"name":"links","type":"string","nullable":true,"metadata":{}},{"name":"image_count","type":"long","nullable":true,"metadata":{}},{"name":"images","type":"string","nullable":true,"metadata":{}},{"name":"script_count","type":"long","nullable":true,"metadata":{}},{"name":"scripts","type":"string","nullable":true,"metadata":{}}]}
# DEBUG:py4j.clientserver:Command to send: c
# o107
# sessionLocalTimeZone
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: c
# o107
# sessionLocalTimeZone
# e
#
# DEBUG:py4j.clientserver:Answer received: !ysEtc/UTC
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !ysEtc/UTC
# DEBUG:py4j.clientserver:Command to send: c
# o107
# pandasStructHandlingMode
# e
#
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Command to send: c
# o107
# pandasStructHandlingMode
# e
#
# DEBUG:py4j.clientserver:Answer received: !yslegacy
# 2025-05-11 15:35:24 [py4j.clientserver] DEBUG: Answer received: !yslegacy
# ✅ Cleaned crawl data saved to CSV, Parquet, and sample CSV.

# %%
from google.colab import files
import zipfile
import os

# Zip folders for easier download
def zip_and_download_folder(folder_path, zip_name):
    zipf = zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED)
    for root, dirs, files_in_dir in os.walk(folder_path):
        for file in files_in_dir:
            full_path = os.path.join(root, file)
            relative_path = os.path.relpath(full_path, folder_path)
            zipf.write(full_path, os.path.join(os.path.basename(folder_path), relative_path))
    zipf.close()
    files.download(zip_name)

# Download zipped folders
zip_and_download_folder("cleaned_crawled_data_csv", "cleaned_crawled_data_csv.zip")
zip_and_download_folder("cleaned_crawled_data_parquet", "cleaned_crawled_data_parquet.zip")

# Download sample CSV file
files.download("sample_cleaned_crawled_data.csv")

# %% [markdown]
# # **6. Spider Scrapy**

# %%
# !python3 my_spider.py

# %% [markdown]
# # **7. download Scrapy data Json**

# %%
from google.colab import files
files.download("scraped_data.json")
